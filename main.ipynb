# %%
# %pip install -r requirements.txt --quiet
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_community.document_loaders import UnstructuredPowerPointLoader


powerpoint_loader = UnstructuredPowerPointLoader("data/pptx/DDBS Lecture1.ppt")

data = powerpoint_loader.load()

# data

# %%
# print(data[0].page_content)
pages = data[0].page_content.split("<number>")
cleaned_pages = [page.strip() for page in pages]
# Output the result to check the separated pages

print("Filename: ", data[0].metadata["source"])
print("-----------------------")
for i, page in enumerate(cleaned_pages):
    print(f"Page {i+1}:")
    print(page)
    print("\n" + "=" * 50 + "\n")
# Out:
# Filename:  data/pptx/DDBS Lecture1.ppt
# -----------------------
# Page 1:
# Andrew Mwaura
#
# Lecture 1
#
# October 17, 2024
#
# Distributed Databases - CSC451
#
# ...
#
# Page 2:
# Outline
#
# Motivation of Distributed Databases
#
# Distributed Data Processing Vs Distributed Database
#
# Distributed Databases
#
# Partitioning
#
# Replication
#
# Advantages and Disadvantages of Distributed Databases
#
# October 17, 2024
#
# Distributed Databases - CSC451
#
# ...
#
# Page 3:
# Motivation of Distributed Databases
#
# October 17, 2024
#
# Distributed Databases - CSC451
#
# ...
#
# Page 4:
# Distributed Database - A User’s View
#
# October 17, 2024
#
# Distributed Databases - CSC451
#
# ...
#
# Page 5:
# Distributed Database - Reality
#
# October 17, 2024
#
# Distributed Databases - CSC451
#
# ...
#
# Page 6:
# Distributed Database
#
# Applications
#
# Corporate MIS
#
# Hotel Chains
#
# Manufacturing
#
# October 17, 2024
#
# Distributed Databases - CSC451
#
# ...
#
# Page 7:
# Application Peer-to-Peer Databases
#
# ...
